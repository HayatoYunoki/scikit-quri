# %%
import numpy as np
from scikit_quri.circuit import LearningCircuit
from quri_parts.core.operator import Operator, pauli_label
from quri_parts.core.estimator.sampling import create_sampling_concurrent_estimator
from quri_parts.core.sampling.shots_allocator import create_proportional_shots_allocator
from quri_parts.core.measurement import bitwise_commuting_pauli_measurement

pi = np.pi

# %% [markdown]
# # Code you have to change.

# %%
# Learning Parameters
input_params = []
learning_params = [pi/4, pi/3]

operator = Operator({
    pauli_label("Z0"): 1.0,
    pauli_label("Z1"): 1.0
    })

# %%
# Create LearningCircuit instance
learning_circuit = LearningCircuit(2)
learning_circuit.add_H_gate(0)
learning_circuit.add_CNOT_gate(0, 1)
learning_circuit.add_parametric_RX_gate(0)
learning_circuit.add_parametric_RY_gate(1)
# Out:
# 1

# %%
# Sampler and Estimator
from concurrent.futures import ThreadPoolExecutor
from quri_parts_oqtopus.sampler import create_oqtopus_concurrent_sampler

shots = 1024

concurrency = len(learning_params)
executor = ThreadPoolExecutor(concurrency)
sampler = create_oqtopus_concurrent_sampler(executor, concurrency)

measurement_factory = bitwise_commuting_pauli_measurement
shots_allocator = create_proportional_shots_allocator()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Sampler and Estimator
#       2 from concurrent.futures import ThreadPoolExecutor
# ----> 3 from quri_parts_oqtopus.sampler import create_oqtopus_concurrent_sampler
#       5 shots = 1024
#       7 concurrency = len(learning_params)
#
# File ~/Desktop/QML/tutorial/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts_oqtopus/sampler.py:19
#      16 if TYPE_CHECKING:
#      17     from concurrent.futures import Executor
# ---> 19 backend = OqtopusSamplingBackend()
#      22 # MeasurementCounts and SamplingCounts are equivalent
#      23 def _sample(circuit: ImmutableQuantumCircuit, shots: int) -> MeasurementCounts:
#
# File ~/Desktop/QML/tutorial/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts_oqtopus/backend/sampling.py:547, in OqtopusSamplingBackend.__init__(self, config)
#     540         config = OqtopusConfig(
#     541             url=url,
#     542             api_token=api_token,
#     543             proxy=proxy,
#     544         )
#     545     # load config from file
#     546     else:
# --> 547         config = OqtopusConfig.from_file()
#     549 # construct JobApi
#     550 rest_config = Configuration()
#
# File ~/Desktop/QML/tutorial/scikit-quri/.venv/lib/python3.10/site-packages/quri_parts_oqtopus/backend/config.py:125, in OqtopusConfig.from_file(section, path)
#     122 parser = configparser.ConfigParser()
#     123 parser.read(pat_expanduser, encoding="utf-8")
#     124 return OqtopusConfig(
# --> 125     url=parser[section]["url"],
#     126     api_token=parser[section]["api_token"],
#     127     proxy=parser[section].get("proxy", None),
#     128 )
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/configparser.py:965, in RawConfigParser.__getitem__(self, key)
#     963 def __getitem__(self, key):
#     964     if key != self.default_section and not self.has_section(key):
# --> 965         raise KeyError(key)
#     966     return self._proxies[key]
#
# KeyError: 'default'

# %% [markdown]
# # Code you don't have to change.

# %%
# Execute hadamard_grad
estimator = create_sampling_concurrent_estimator(
    total_shots=shots,
    sampler=sampler,
    measurement_factory=measurement_factory,
    shots_allocator=shots_allocator,
    )

gradients = learning_circuit.hadamard_gradient(
    np.array(input_params),
    np.array(learning_params),
    operator,
    estimator,
)

print("Gradients:", gradients)
